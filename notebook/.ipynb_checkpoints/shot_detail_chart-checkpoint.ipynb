# %%
from nba_api.stats.endpoints.shotchartdetail import ShotChartDetail
import requests
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Example: James Harden, 2014-15 Regular Season, all teams (team_id=0)
shot_chart = ShotChartDetail(
    team_id=0,
    player_id=201935,
    season_nullable="2014-15",
    season_type_all_star="Regular Season"
)

# %%
shot_df = shot_chart.shot_chart_detail.get_data_frame()
print(shot_df.head())
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0  Shot Chart Detail  0021400003             41     201935  James Harden
# 1  Shot Chart Detail  0021400003            120     201935  James Harden
# 2  Shot Chart Detail  0021400003            241     201935  James Harden
# 3  Shot Chart Detail  0021400003            252     201935  James Harden
# 4  Shot Chart Detail  0021400003            272     201935  James Harden
#
#       TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612745  Houston Rockets       1                  8                 21
# 1  1610612745  Houston Rockets       1                  2                 38
# 2  1610612745  Houston Rockets       2                  5                 49
# 3  1610612745  Houston Rockets       2                  4                 42
# 4  1610612745  Houston Rockets       2                  2                 48
#
#    ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE LOC_X LOC_Y  \
# 0  ...   Left Side Center(LC)          24+ ft.            25  -232   110
# 1  ...              Center(C)  Less Than 8 ft.             2    -8    22
# 2  ...              Center(C)          24+ ft.            24   -21   249
# 3  ...  Right Side Center(RC)          24+ ft.            24   181   165
# 4  ...              Center(C)  Less Than 8 ft.             2   -18    11
#
#   SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM
# 0                   1               1   20141028  LAL  HOU
# 1                   1               1   20141028  LAL  HOU
# 2                   1               1   20141028  LAL  HOU
# 3                   1               1   20141028  LAL  HOU
# 4                   1               1   20141028  LAL  HOU
#
# [5 rows x 24 columns]

# %%
# draw a basketball court with matplotlib
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12, 11))

# %%
plt.scatter(shot_df.LOC_X, shot_df.LOC_Y)

# %%
plt.show()
